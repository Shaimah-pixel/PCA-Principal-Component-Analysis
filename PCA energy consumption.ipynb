# %%
#This dataset is designed for predicting energy consumption based on various building features and environmental factors. It contains data for multiple building types, square footage, the number of occupants, appliances used, average temperature, and the day of the week. The goal is to build a predictive model to estimate energy consumption using these attributes.

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\shamzkha\Documents\train_energy_data.csv")

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.head()
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential            7063                   76               10
# 1    Commercial           44372                   66               45
# 2    Industrial           19255                   37               17
# 3   Residential           13265                   14               41
# 4    Commercial           13375                   26               18
#
#    Average Temperature Day of Week  Energy Consumption
# 0                29.84     Weekday             2713.95
# 1                16.72     Weekday             5744.99
# 2                14.30     Weekend             4101.24
# 3                32.82     Weekday             3009.14
# 4                11.92     Weekday             3279.17

# %%
data=data.rename(columns={"Building Type":"Building_Type"})

# %%
data=data.rename(columns={"Day of Week":"Day_of_Week"})

# %%
data.isnull().sum()
# Out:
# Building_Type          0
# Square Footage         0
# Number of Occupants    0
# Appliances Used        0
# Average Temperature    0
# Day_of_Week            0
# Energy Consumption     0
# dtype: int64

# %%
data.dtypes
# Out:
# Building_Type           object
# Square Footage           int64
# Number of Occupants      int64
# Appliances Used          int64
# Average Temperature    float64
# Day_of_Week             object
# Energy Consumption     float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.Building_Type=le.fit_transform(data.Building_Type)

# %%
data.Day_of_Week=le.fit_transform(data.Day_of_Week)

# %%
data.dtypes
# Out:
# Building_Type            int32
# Square Footage           int64
# Number of Occupants      int64
# Appliances Used          int64
# Average Temperature    float64
# Day_of_Week              int32
# Energy Consumption     float64
# dtype: object

# %%
data.head()
# Out:
#    Building_Type  Square Footage  Number of Occupants  Appliances Used  \
# 0              2            7063                   76               10
# 1              0           44372                   66               45
# 2              1           19255                   37               17
# 3              2           13265                   14               41
# 4              0           13375                   26               18
#
#    Average Temperature  Day_of_Week  Energy Consumption
# 0                29.84            0             2713.95
# 1                16.72            0             5744.99
# 2                14.30            1             4101.24
# 3                32.82            0             3009.14
# 4                11.92            0             3279.17

# %%
data_x=data.iloc[:,0:6]
data_x.head()
# Out:
#    Building_Type  Square Footage  Number of Occupants  Appliances Used  \
# 0              2            7063                   76               10
# 1              0           44372                   66               45
# 2              1           19255                   37               17
# 3              2           13265                   14               41
# 4              0           13375                   26               18
#
#    Average Temperature  Day_of_Week
# 0                29.84            0
# 1                16.72            0
# 2                14.30            1
# 3                32.82            0
# 4                11.92            0

# %%
data_y=data.iloc[:,6]
data_y.head()
# Out:
# 0    2713.95
# 1    5744.99
# 2    4101.24
# 3    3009.14
# 4    3279.17
# Name: Energy Consumption, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
from sklearn.decomposition import PCA
pca=PCA()

# %%
ss.fit(data_x)
# Out:
# StandardScaler()

# %%
ss_data=ss.transform(data_x)

# %%
pca.fit(ss_data)
# Out:
# PCA()

# %%
data_x_pca1=pca.transform(ss_data)
data_x_pca1
# Out:
# array([[ 1.33810764e+00,  8.17611697e-01, -5.00919268e-01,
#         -1.46133952e+00,  1.30101970e+00,  8.25285462e-01],
#        [-1.07745653e+00, -1.28029727e+00, -1.23550343e+00,
#         -1.30328376e-01, -1.67254265e+00, -1.48829440e-01],
#        [-6.81265282e-01,  2.20052232e-01,  9.81410993e-01,
#          8.94203132e-01,  4.04689342e-01,  8.12752676e-01],
#        ...,
#        [ 9.57834622e-01, -9.16359058e-01, -1.12638585e-01,
#         -1.84287804e+00, -1.44467352e+00, -8.38450426e-02],
#        [-8.26179560e-01, -5.16823318e-01, -1.80022369e-01,
#          4.84850520e-01,  2.09711014e+00,  2.88457848e-01],
#        [ 2.71484733e-01,  1.06523013e-01,  1.97400691e+00,
#         -1.26586734e+00, -1.93681426e-03, -2.74521405e-01]])

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 1.0

# %%
pca.explained_variance_ratio_
# Out:
# array([0.18460455, 0.17331037, 0.16895031, 0.16257355, 0.15680401,
#        0.15375721])

# %%
pd.DataFrame(data_x_pca1).corr()
# Out:
#               0             1             2             3             4  \
# 0  1.000000e+00 -5.333756e-17 -5.741678e-17  1.591472e-16 -2.348838e-16
# 1 -5.333756e-17  1.000000e+00  3.100778e-17 -9.397582e-17  1.846991e-17
# 2 -5.741678e-17  3.100778e-17  1.000000e+00  2.558993e-16  8.806856e-17
# 3  1.591472e-16 -9.397582e-17  2.558993e-16  1.000000e+00 -7.336541e-18
# 4 -2.348838e-16  1.846991e-17  8.806856e-17 -7.336541e-18  1.000000e+00
# 5  1.818232e-16  3.521384e-16  2.164079e-16  6.138493e-16  2.475686e-17
#
#               5
# 0  1.818232e-16
# 1  3.521384e-16
# 2  2.164079e-16
# 3  6.138493e-16
# 4  2.475686e-17
# 5  1.000000e+00

# %%
from sklearn import linear_model
ln=linear_model.LinearRegression()

# %%
data_x_pca1_df=pd.DataFrame(data_x_pca1)

# %%
ln.fit(data_x_pca1_df.iloc[:,[0,1,2,3,4]],data_y)
# Out:
# LinearRegression()

# %%
ln.score(data_x_pca1_df.iloc[:,[0,1,2,3,4]],data_y)
# Out:
# 0.8450725172359816

# %%
#Since this score comes from a linear regression model, the value of 0.845 likely represents the R-squared (R²) value, which indicates the proportion of variance in the target variable (data_y) that is explained by the independent variables (data_x_pca1_df).

#In this case, an R-squared value of 0.845 means that approximately 84.5% of the variability in data_y can be explained by the linear relationship with the predictors (the columns of data_x_pca1_df).
